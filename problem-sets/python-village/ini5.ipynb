# %%
import numpy as np
import pandas as pd

# %%
f = open("rosalind_ini5.txt", 'r')

txt = f.readlines()
f_final_5 = open('f_final_5.txt', 'w')

for line in range(len(txt)):
    if line % 2 == 1:
        f_final_5.write(str(txt[line]))

f_final_5.close()
