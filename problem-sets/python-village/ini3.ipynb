# %%
import numpy as np

# %%
string = 'J4jelYAlpesVzF1HfvhqRCAbNp9hcrigy8Yc3IQromIpzhMRCHHNfSb3BspJw9uJpoitTU4vonIq4jItWJ0OgQGBzNgHQCjCjb7dlCkfueHyCRIyamericanusExE1MEMf0dAfYFxmUgdFvW55RZ7wpktJQFDfJpE0JQRUE'

# %%
a = 6
b = 10
c = 112
d = 121

first_text = string[6:10+1]
second_text = string[112:121+1]

final_text = first_text + " " + second_text

# %%
print(final_text)
# Out:
# Alpes americanus
