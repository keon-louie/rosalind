# %%
watson = '...'
crick = ''

for _ in watson:
    if _ == 'A':
        crick += 'T'
    elif _ == 'C':
        crick += 'G'
    elif _ == 'G':
        crick += 'C'
    else:
        crick += 'A'

crick = crick[::-1]
print(crick)
# Out:
# ...
