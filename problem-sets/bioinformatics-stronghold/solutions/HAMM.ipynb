# %%
with open("../problem_files/rosalind_hamm.txt", 'r') as f:
    a = f.readline()
    b = f.readline()


hamming = 0
for base in range(len(a)):
    if a[base] != b[base]:
        hamming += 1

print(hamming)
# Out:
# 441
