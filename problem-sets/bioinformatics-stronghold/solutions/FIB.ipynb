# %%
import numpy as np
import scipy as scp
import pandas as pd

# %%
n = 32
k = 5

f1 = 1
f2 = 1
f = np.zeros(n)
f[0] = 1
f[1] = 1

for i in range(2, n):
    f[i] = f[i - 2] * k + f[i - 1]

print(f[-1])
# Out:
# 40238153982301.0
